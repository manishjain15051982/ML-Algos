# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

import matplotlib.pyplot as plt

# %%
train = pd.read_csv("E:\\Machine Learning\\Competitions - Kaggle\\Leaf Classification\\Data\\train\\train.csv")
test = pd.read_csv("E:\\Machine Learning\\Competitions - Kaggle\\Leaf Classification\\Data\\test\\test.csv")

# %%
train.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8    ...      texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0    ...       0.007812   0.000000
# 1  0.025391  0.001953  0.019531      0.0    ...       0.000977   0.000000
# 2  0.003906  0.005859  0.068359      0.0    ...       0.154300   0.000000
# 3  0.021484  0.019531  0.023438      0.0    ...       0.000000   0.000977
# 4  0.013672  0.015625  0.005859      0.0    ...       0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# ...

# %%
train.describe()
# Out:
#                 id     margin1     margin2     margin3     margin4  \
# count   990.000000  990.000000  990.000000  990.000000  990.000000
# mean    799.595960    0.017412    0.028539    0.031988    0.023280
# std     452.477568    0.019739    0.038855    0.025847    0.028411
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     415.250000    0.001953    0.001953    0.013672    0.005859
# 50%     802.500000    0.009766    0.011719    0.025391    0.013672
# 75%    1195.500000    0.025391    0.041016    0.044922    0.029297
# max    1584.000000    0.087891    0.205080    0.156250    0.169920
#
#           margin5     margin6     margin7     margin8     margin9     ...      \
# count  990.000000  990.000000  990.000000  990.000000  990.000000     ...
# mean     0.014264    0.038579    0.019202    0.001083    0.007167     ...
# std      0.018390    0.052030    0.017511    0.002743    0.008933     ...
# ...

# %%
train.columns
# Out:
# Index(['id', 'species', 'margin1', 'margin2', 'margin3', 'margin4', 'margin5',
#        'margin6', 'margin7', 'margin8',
#        ...
#        'texture55', 'texture56', 'texture57', 'texture58', 'texture59',
#        'texture60', 'texture61', 'texture62', 'texture63', 'texture64'],
#       dtype='object', length=194)

# %%
X_train =train

# %%
X_train.columns
# Out:
# Index(['id', 'species', 'margin1', 'margin2', 'margin3', 'margin4', 'margin5',
#        'margin6', 'margin7', 'margin8',
#        ...
#        'texture55', 'texture56', 'texture57', 'texture58', 'texture59',
#        'texture60', 'texture61', 'texture62', 'texture63', 'texture64'],
#       dtype='object', length=194)

# %%
X_val = X_train[X_train['id']>1000]

# %%
X_train = X_train[X_train.id<=1000]

# %%
X_val.columns
# Out:
# Index(['id', 'species', 'margin1', 'margin2', 'margin3', 'margin4', 'margin5',
#        'margin6', 'margin7', 'margin8',
#        ...
#        'texture55', 'texture56', 'texture57', 'texture58', 'texture59',
#        'texture60', 'texture61', 'texture62', 'texture63', 'texture64'],
#       dtype='object', length=194)

# %%
y_val = X_val.species

# %%
y_val.values
# Out:
# array(['Populus_Grandidentata', 'Acer_Opalus', 'Acer_Saccharinum',
#        'Alnus_Sieboldiana', 'Acer_Mono', 'Quercus_Ilex',
#        'Quercus_Coccinea', 'Quercus_Semecarpifolia', 'Acer_Platanoids',
#        'Betula_Pendula', 'Phildelphus', 'Quercus_Trojana',
#        'Crataegus_Monogyna', 'Acer_Circinatum', 'Alnus_Rubra',
#        'Pterocarya_Stenoptera', 'Quercus_Palustris', 'Salix_Fragilis',
#        'Quercus_Coccifera', 'Tilia_Platyphyllos', 'Magnolia_Heptapeta',
#        'Olea_Europaea', 'Arundinaria_Simonii', 'Lithocarpus_Edulis',
#        'Quercus_Castaneifolia', 'Arundinaria_Simonii',
#        'Tilia_Platyphyllos', 'Acer_Palmatum', 'Salix_Intergra',
#        'Rhododendron_x_Russellianum', 'Quercus_Castaneifolia',
#        'Magnolia_Salicifolia', 'Quercus_Castaneifolia', 'Betula_Pendula',
#        'Ilex_Cornuta', 'Tilia_Tomentosa', 'Quercus_Chrysolepis',
#        'Tilia_Oliveri', 'Quercus_Suber', 'Crataegus_Monogyna',
# ...

# %%
del X_val['species']

# %%
X_val.columns
# Out:
# Index(['id', 'margin1', 'margin2', 'margin3', 'margin4', 'margin5', 'margin6',
#        'margin7', 'margin8', 'margin9',
#        ...
#        'texture55', 'texture56', 'texture57', 'texture58', 'texture59',
#        'texture60', 'texture61', 'texture62', 'texture63', 'texture64'],
#       dtype='object', length=193)

# %%
X_val.head()
# Out:
#        id   margin1   margin2   margin3   margin4   margin5   margin6  \
# 632  1001  0.001953  0.009766  0.126950  0.000000  0.000000  0.017578
# 633  1002  0.009766  0.033203  0.037109  0.003906  0.009766  0.015625
# 634  1003  0.000000  0.000000  0.029297  0.027344  0.031250  0.000000
# 635  1004  0.001953  0.011719  0.013672  0.001953  0.025391  0.013672
# 636  1005  0.023438  0.017578  0.027344  0.009766  0.001953  0.019531
#
#       margin7   margin8  margin9    ...      texture55  texture56  texture57  \
# 632  0.017578  0.005859  0.00000    ...       0.047852   0.000000   0.007812
# 633  0.041016  0.005859  0.00000    ...       0.002930   0.000000   0.010742
# 634  0.000000  0.005859  0.03125    ...       0.021484   0.000000   0.041992
# 635  0.017578  0.000000  0.00000    ...       0.000000   0.000977   0.000000
# 636  0.033203  0.000000  0.00000    ...       0.210940   0.000000   0.021484
#
#      texture58  texture59  texture60  texture61  texture62  texture63  \
# ...

# %%
X_train.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8    ...      texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0    ...       0.007812   0.000000
# 1  0.025391  0.001953  0.019531      0.0    ...       0.000977   0.000000
# 2  0.003906  0.005859  0.068359      0.0    ...       0.154300   0.000000
# 3  0.021484  0.019531  0.023438      0.0    ...       0.000000   0.000977
# 4  0.013672  0.015625  0.005859      0.0    ...       0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# ...

# %%
y_train = X_train.species

# %%
del X_train['species']

# %%
X_train.id.count
# Out:
# <bound method Series.count of 0         1
# 1         2
# 2         3
# 3         5
# 4         6
# 5         8
# 6        10
# 7        11
# 8        14
# 9        15
# 10       17
# 11       18
# 12       20
# 13       21
# 14       22
# 15       25
# 16       26
# 17       27
# 18       29
# 19       30
# 20       31
# 21       32
# 22       34
# 23       35
# 24       37
# 25       38
# 26       40
# 27       42
# 28       43
# 29       45
#        ...
# 602     956
# 603     958
# 604     959
# 605     960
# 606     961
# 607     962
# 608     963
# 609     966
# 610     968
# 611     969
# 612     970
# 613     971
# 614     972
# 615     975
# 616     976
# 617     978
# 618     979
# 619     981
# 620     983
# 621     985
# 622     987
# 623     989
# 624     990
# 625     992
# 626     993
# 627     994
# 628     995
# 629     996
# 630     999
# 631    1000
# Name: id, Length: 632, dtype: int64>

# %%
X_val.head()
# Out:
#        id   margin1   margin2   margin3   margin4   margin5   margin6  \
# 632  1001  0.001953  0.009766  0.126950  0.000000  0.000000  0.017578
# 633  1002  0.009766  0.033203  0.037109  0.003906  0.009766  0.015625
# 634  1003  0.000000  0.000000  0.029297  0.027344  0.031250  0.000000
# 635  1004  0.001953  0.011719  0.013672  0.001953  0.025391  0.013672
# 636  1005  0.023438  0.017578  0.027344  0.009766  0.001953  0.019531
#
#       margin7   margin8  margin9    ...      texture55  texture56  texture57  \
# 632  0.017578  0.005859  0.00000    ...       0.047852   0.000000   0.007812
# 633  0.041016  0.005859  0.00000    ...       0.002930   0.000000   0.010742
# 634  0.000000  0.005859  0.03125    ...       0.021484   0.000000   0.041992
# 635  0.017578  0.000000  0.00000    ...       0.000000   0.000977   0.000000
# 636  0.033203  0.000000  0.00000    ...       0.210940   0.000000   0.021484
#
#      texture58  texture59  texture60  texture61  texture62  texture63  \
# ...

# %%
X_test =test

# %%
X_test.head()
# Out:
#    id   margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0   4  0.019531  0.009766  0.078125  0.011719  0.003906  0.015625  0.005859
# 1   7  0.007812  0.005859  0.064453  0.009766  0.003906  0.013672  0.007812
# 2   9  0.000000  0.000000  0.001953  0.021484  0.041016  0.000000  0.023438
# 3  12  0.000000  0.000000  0.009766  0.011719  0.017578  0.000000  0.003906
# 4  13  0.001953  0.000000  0.015625  0.009766  0.039062  0.000000  0.009766
#
#    margin8   margin9    ...      texture55  texture56  texture57  texture58  \
# 0      0.0  0.005859    ...       0.006836   0.000000   0.015625   0.000977
# 1      0.0  0.033203    ...       0.000000   0.000000   0.006836   0.001953
# 2      0.0  0.011719    ...       0.128910   0.000000   0.000977   0.000000
# 3      0.0  0.003906    ...       0.012695   0.015625   0.002930   0.036133
# 4      0.0  0.005859    ...       0.000000   0.042969   0.016602   0.010742
#
# ...

# %%
import tensorflow as tf
from tensorflow.python.framework import ops
from tf_utils import load_dataset, random_mini_batches, convert_to_one_hot, predict

# %%
X_train_np = X_train.as_matrix

# %%
X_train_tensor = tf.constant(X_train_np, dtype = tf.float32, shape=[632,193])

# %%
X_train=X_train.astype(np.float32)
X_val=X_val.astype(np.float32)
X_test=X_test.astype(np.float32)
Y_train=y_train
Y_val=y_val

# %%
y_train.head
# Out:
# <bound method NDFrame.head of 0                 Acer_Opalus
# 1       Pterocarya_Stenoptera
# 2        Quercus_Hartwissiana
# 3             Tilia_Tomentosa
# 4          Quercus_Variabilis
# 5        Magnolia_Salicifolia
# 6         Quercus_Canariensis
# 7               Quercus_Rubra
# 8             Quercus_Brantii
# 9              Salix_Fragilis
# 10            Zelkova_Serrata
# 11      Betula_Austrosinensis
# 12            Quercus_Pontica
# 13             Quercus_Afares
# 14          Quercus_Coccifera
# 15            Fagus_Sylvatica
# 16                Phildelphus
# 17              Acer_Palmatum
# 18          Quercus_Pubescens
# 19          Populus_Adenopoda
# 20            Quercus_Trojana
# 21         Quercus_Variabilis
# 22          Alnus_Sieboldiana
# 23               Quercus_Ilex
# 24        Arundinaria_Simonii
# 25            Acer_Platanoids
# 26     Quercus_Phillyraeoides
# 27           Cornus_Chinensis
# 28     Quercus_Phillyraeoides
# 29            Fagus_Sylvatica
# ...

# %%
# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Logistic Regression

logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
Y_pred = logreg.predict(X_test)
acc_log = round(logreg.score(X_val, Y_val) * 100, 2)
acc_log
# Out:
# 1.3999999999999999

# %%
# Support Vector Machines

svc = SVC()
svc.fit(X_train, Y_train)
Y_pred = svc.predict(X_val)
acc_svc = round(svc.score(X_train, Y_train) * 100, 2)
acc_svc
# Out:
# 16.77

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_val)
acc_knn = round(knn.score(X_train, Y_train) * 100, 2)
acc_knn
# Out:
# 34.18

# %%
# Gaussian Naive Bayes

gaussian = GaussianNB()
gaussian.fit(X_train, Y_train)
Y_pred = gaussian.predict(X_val)
acc_gaussian = round(gaussian.score(X_train, Y_train) * 100, 2)
acc_gaussian
# Out:
# 99.370000000000005

# %%
# Perceptron

perceptron = Perceptron()
perceptron.fit(X_train, Y_train)
Y_pred = perceptron.predict(X_val)
acc_perceptron = round(perceptron.score(X_train, Y_train) * 100, 2)
acc_perceptron
# Out:
# 0.79000000000000004

# %%
# Linear SVC

linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)
Y_pred = linear_svc.predict(X_val)
acc_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)
acc_linear_svc
# Out:
# 1.8999999999999999

# %%
# Stochastic Gradient Descent

sgd = SGDClassifier()
sgd.fit(X_train, Y_train)
Y_pred = sgd.predict(X_val)
acc_sgd = round(sgd.score(X_train, Y_train) * 100, 2)
acc_sgd
# Out:
# 1.1100000000000001

# %%
# Decision Tree

decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, Y_train)
Y_pred = decision_tree.predict(X_val)
acc_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
acc_decision_tree
# Out:
# 100.0

# %%
# Random Forest

random_forest = RandomForestClassifier(n_estimators=1000,bootstrap=True)
random_forest.fit(X_train, Y_train)
Y_pred = random_forest.predict_proba(X_test)
random_forest.score(X_train, Y_train)
acc_random_forest = round(random_forest.score(X_val, Y_val) * 100, 2)
acc_random_forest
# Out:
# 96.650000000000006

# %%
acc_random_forest = round(random_forest.score(X_val, Y_val) * 100, 2)
acc_random_forest
# Out:
# 96.650000000000006

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Perceptron', 
              'Stochastic Gradient Decent', 'Linear SVC', 
              'Decision Tree'],
    'Score': [acc_svc, acc_knn, acc_log, 
              acc_random_forest, acc_gaussian, acc_perceptron, 
              acc_sgd, acc_linear_svc, acc_decision_tree]})
models.sort_values(by='Score', ascending=False)
# Out:
#                         Model   Score
# 8               Decision Tree  100.00
# 4                 Naive Bayes   99.37
# 3               Random Forest   96.65
# 1                         KNN   34.18
# 0     Support Vector Machines   16.77
# 7                  Linear SVC    1.90
# 2         Logistic Regression    1.40
# 6  Stochastic Gradient Decent    1.11
# 5                  Perceptron    0.79

# %%
# Random Forest

random_forest = RandomForestClassifier(n_estimators=2000,bootstrap=True,max_features='log2',min_samples_leaf =2)
random_forest.fit(X_train, Y_train)
Y_pred = random_forest.predict_proba(X_test)
random_forest.score(X_train, Y_train)
acc_random_forest_train = round(random_forest.score(X_train, Y_train) * 100, 2)
acc_random_forest_train
#acc_random_forest = round(random_forest.score(X_val, Y_val) * 100, 2)
#acc_random_forest
# Out:
# 100.0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder().fit(Y_train)
Y_train = le.transform(Y_train)

# %%
Y_val = le.transform(Y_val)

# %%
Y_val
# Out:
# array([45,  3,  9, 13,  2, 66, 59, 79,  6, 17, 43, 83, 26,  1, 12, 49, 71,
#        89, 58, 93, 39, 42, 15, 38, 55, 15, 93,  4, 90, 88, 55, 40, 55, 17,
#        34, 94, 57, 92, 81, 26, 60, 89, 49, 89, 30, 65, 58,  4, 19,  4, 76,
#        74, 71, 21, 54, 13, 16, 72, 68, 62, 61, 25, 72,  7, 12, 18, 77, 90,
#        62, 14,  3, 78, 65, 37, 27, 50, 95, 98, 60, 72, 58, 38, 87, 93, 19,
#         7, 83, 50,  3, 91, 77,  7, 64, 61, 69, 23, 76, 65, 48, 41, 92, 20,
#        91, 18, 70,  9,  9, 29, 85, 67,  0, 35, 98, 91, 90, 31, 53, 39, 24,
#        85, 96, 17,  7, 11, 96, 39, 56, 90, 79, 45, 64, 97, 41, 19, 74, 11,
#        10, 62, 95, 28, 96, 10,  7, 68,  7, 93, 34, 42, 68, 41, 14, 22, 58,
#        12, 71, 27, 98, 72, 91,  3, 43, 19, 61, 75, 20, 81, 63, 67, 56, 26,
#        47, 11, 31, 57, 62, 66, 19, 75, 97, 94, 13, 75, 95, 32, 50, 97, 52,
#        87, 32,  3, 47, 77, 48, 33, 73, 64, 49, 68, 43, 94, 77, 68, 47, 82,
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
# Gradient Boosting Trees

Gradient_Boosting = GradientBoostingClassifier(n_estimators=1000,min_samples_leaf=4)
Gradient_Boosting.fit(X_train, Y_train)
#Y_pred = Gradient_Boosting.predict_proba(X_test)

acc_gradient_boosting_train = round(Gradient_Boosting.score(X_train, Y_train) * 100, 2)
acc_gradient_boosting_train
#acc_random_forest = round(random_forest.score(X_val, Y_val) * 100, 2)
#acc_random_forest
# Out:
# 95.890000000000001

# %%
acc_gradient_boosting_val = round(Gradient_Boosting.score(X_val, Y_val) * 100, 2)
acc_gradient_boosting_val

# %%
from sklearn.model_selection import GridSearchCV
param_grid= {'learning_rate' : [0.1,0.05,0.02,0.01], 'max_depth':[4,6], 'min_samples_leaf':[3,5,9,17], 
             'max_features':[1.0,0.3,0.1]}
est= GradientBoostingClassifier(n_estimators=3000)
gs_cv=GridSearchCV(est,param_grid).fit(X_train,Y_train)
gs_cv.best_params_

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y_train=le.fit(Y_train)

# %%
Y_train
# Out:
# LabelEncoder()

# %%
import sklearn.metrics as met

# %%
acc_gradient_boosting_val = round(Gradient_Boosting.score(X_val, Y_val) * 100, 2)
acc_gradient_boosting_val
# Out:
# 44.409999999999997

# %%
logloss_random_forest = met.log_loss(Y_val, Y_val_pred, eps=1e-15)
logloss_random_forest

# %%
Y_pred.shape
# Out:
# (594, 99)

# %%
Y_pred[1]
# Out:
# array([  2.49277683e-100,   1.91832331e-097,   1.65595161e-081,
#          1.69666383e-025,   1.14374119e-166,   1.28634963e-085,
#          2.24505305e-052,   3.02413647e-104,   2.88960107e-092,
#          3.25182637e-111,   1.93569955e-054,   1.49642261e-100,
#          2.46864826e-063,   1.69046397e-088,   3.39241644e-118,
#          4.34605925e-086,   1.51305020e-109,   2.83864788e-104,
#          4.38741787e-097,   3.60574040e-049,   4.45649685e-096,
#          2.31615492e-081,   3.28080243e-072,   4.46851710e-119,
#          6.67467887e-123,   2.45542006e-121,   4.44808548e-056,
#          2.49587043e-108,   1.70998166e-051,   4.36036993e-075,
#          4.36981546e-060,   4.72070052e-051,   1.33026190e-064,
#          6.53149158e-101,   1.04720574e-076,   2.32348854e-131,
#          6.58308704e-040,   3.69271117e-129,   4.42806559e-110,
#          2.89587400e-090,   5.06582291e-091,   3.46592142e-065,
#          5.16974135e-072,   8.10128189e-075,   5.85159945e-107,
# ...

# %%
submission = pd.DataFrame(Y_pred, columns =random_forest.classes_)

# %%
submission.insert(0,'id',X_test['id'])

# %%
submission['id']=submission['id'].astype(int)

# %%
submission.to_csv('E:\\Machine Learning\\Competitions - Kaggle\\Leaf Classification/submission2.csv', index=False)

# %%
submission.head
# Out:
# <bound method NDFrame.head of        id  Acer_Capillipes  Acer_Circinatum  Acer_Mono  Acer_Opalus  \
# 0       4         0.000000         0.005504   0.000000     0.000114
# 1       7         0.004730         0.001057   0.031103     0.022930
# 2       9         0.003803         0.338417   0.001421     0.000387
# 3      12         0.013201         0.024261   0.009092     0.014742
# 4      13         0.022531         0.031261   0.000909     0.000263
# 5      16         0.004425         0.000971   0.009186     0.067886
# 6      19         0.009578         0.003123   0.013362     0.080522
# 7      23         0.003304         0.003199   0.006301     0.005926
# 8      24         0.009565         0.019766   0.005439     0.001668
# 9      28         0.026618         0.022255   0.000680     0.003698
# 10     33         0.009899         0.000241   0.006616     0.011036
# 11     36         0.000804         0.002810   0.000000     0.000000
# ...
